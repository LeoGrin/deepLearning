# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import networkx as nx

# %%
import numpy as np

# %%
graph = nx.read_graphml("datasets/lesmiserables.graphml")

# %%
print nx.info(graph)
# Out:
# Name:
# Type: Graph
# Number of nodes: 77
# Number of edges: 254
# Average degree:   6.5974

# %%
list1 = list()
for node in graph.nodes():
    list1.append(node)

# %%
list2 = list()
for src, dst in graph.edges():
    list2.append((src, dst))

# %%
list1[0]
# Out:
# '58'

# %%
graph.node['58']["blah"] = "blah"

# %%
graph.node['58']
# Out:
# {'Modularity Class': 8,
#  'b': 91,
#  'blah': 'blah',
#  'g': 245,
#  'label': u'Enjolras',
#  'r': 91,
#  'size': 42.4,
#  'x': 355.78366,
#  'y': 74.882454}

# %%
pos = nx.spring_layout(graph)

# %%
plt.figure(figsize=(10,8))
nx.draw_networkx_nodes(graph, pos, node_color='b')
nx.draw_networkx_edges(graph, pos)

# %%
nx.degree(graph, '58')
# Out:
# 15

# %%
pr = nx.pagerank(graph)
